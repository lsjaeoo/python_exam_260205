# %%
print("hi")

print("안녕하세요")
# Out:
# hi
# 안녕하세요

# %%
print("good")
# Out:
# good

# %%
print("hi")
# Out:
# hi

# %%
print("bye")
# Out:
# bye

# %%
class Employee:
    def work(self):
        print("직원이 일을 합니다")


class Manager(Employee):
    def work(self):
        super().work()
        print("메니저가 팀을 관리합니다")


manager = Manager()
manager.work()
# Out:
# 직원이 일을 합니다
# 메니저가 팀을 관리합니다

# %%
# 변수, 함수, 클래스 등을 모아서 저장해 둔 것
# 파이썬에 이미 존재하는 모듈

# 수학 계산 모듈
import math
print(math.sqrt(16))
# Out:
# 4.0

# %%
# 랜덤 숫자나 값을 만들어주는
# 난수 모듈
#무작위 값을 생성하는 모듈
# 게임, 추첨, 테스트 데ㅣ터에 사용
import random

# 1부터 100까지 중 랜덤한 숫지 한개 출력
print(random.randint(1, 100))
# Out:
# 64

# %%
# 날짜/시간 모듈
# 날짜와 시간을 다루는 모듈
# 현재 시간 확인, 날짜 계산 사용

import datetime

# 현재 날짜와 시간을 출력
print(datetime.datetime.now())
# Out:
# 2026-02-10 18:50:42.240728

# %%
# 시간 제어 모듈
# 시간 흐름을 제어하는 모듈
# 프로그램을 잠시 멈출때 사용

import time

# 프로그램을 1초 동안 멈춤
time.sleep(1)

# 1초가 지난후 출력
print("1초 후 실행")
# Out:
# 1초 후 실행

# %%
# 시스템 모듈
# 파이썬 실행환경을 다루는 모듈

import sys

# 현재 사용중인 파이썬 버전 출력
print(sys.version)
# Out:
# 3.14.2 (tags/v3.14.2:df79316, Dec  5 2025, 17:18:21) [MSC v.1944 64 bit (AMD64)]

# %%
# 운영체제 모듈
# 운영체제(os)와 관련된 기능 재공
# 파일/폴더 경로 처리에 사용

import os

# 현재 작업중인 폴더 경로 출력
print(os.getcwd())
# Out:
# c:\work\py_exam

# %%
# 데이터 형식 모듈
# JSON 형식으로 데이터를 변환
  #  -JSON: 데이터를 약속된 모양으로 적는 방식
# 웹, API, 파일 저장에 사용
  # - API : 프로그램끼리 대화하는 방법(규칙)

import json

data = {"name" :"jin", "age" : 20 }
print(json.dumps(data))
# Out:
# {"name": "jin", "age": 20}

# %%
# 정규표현식 모듈
# 문자열 패턴 검사 모듈
# 형식 확인(아이디, 이메일 등)에 사용

import re

# 문자열이 "hi"로 시작하는지 확인
print(bool(re.match('hi', 'hi python')))
# Out:
# True

# %%
# CSV 파일 모듈
# CSV(엑셀) 파일을 읽고 쓰는 모듈
# 데이터 저장/분석 기초에 사용

import csv

with open("test.csv", "w", newline="") as f:
    csv.writer(f).writerow(["name", "score"])

# %%
# 자료구조 모듈
# 자료구조를 편하게 쓰도록 도외줌
# 카운트, 큐, 딕셔너리 확장기능 제공

from collections import Counter

#문자열에서 각 글자의 개수를 셈
print(Counter("apple"))
# Out:
# Counter({'p': 2, 'a': 1, 'l': 1, 'e': 1})
