# %%
print("hi")

print("안녕하세요")
# Out:
# hi
# 안녕하세요

# %%
print("bye")
# Out:
# bye

# %%
class Employee:
    def work(self):
        print("직원이 일을 합니다")


class Manager(Employee):
    def work(self):
        super().work()
        print("메니저가 팀을 관리합니다")


manager = Manager()
manager.work()
# Out:
# 직원이 일을 합니다
# 메니저가 팀을 관리합니다
