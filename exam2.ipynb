# %%
# 내가 직접 만든 모듈 불러오기
import ex1

ex1.func1()
# Out:
# '모듈에 있는 첫번째 함수'

# %%
# 내가 직접 만든 모듈 중 원하는 함수만 불러오기
from ex1 import func1, func2

# func1()
# func2()
# 이런식으로만 호출하면 마지막 것만 출력
# 안되는 경우 다시 vscode를 껏다 켜면 됨

print(func1())
print(func2())
# Out:
# 모듈에 있는 첫번째 함수
# 모듈에 있는 두번째 함수

# %%
import sys

print(sys.path)
# Out:
# ['c:\\Users\\my\\AppData\\Local\\Programs\\Python\\Python314\\python314.zip', 'c:\\Users\\my\\AppData\\Local\\Programs\\Python\\Python314\\DLLs', 'c:\\Users\\my\\AppData\\Local\\Programs\\Python\\Python314\\Lib', 'c:\\Users\\my\\AppData\\Local\\Programs\\Python\\Python314', '', 'C:\\Users\\my\\AppData\\Roaming\\Python\\Python314\\site-packages', 'c:\\Users\\my\\AppData\\Local\\Programs\\Python\\Python314\\Lib\\site-packages']
